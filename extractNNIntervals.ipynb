# %%
import sys
# !{sys.executable} -m pip install pandas numpy matplotlib seaborn scipy biosppy hrv-analysis py-ecg-detectors
# Out:
# Requirement already satisfied: pandas in /Users/madamek/Library/Python/3.9/lib/python/site-packages (1.3.0)
# Requirement already satisfied: numpy in /Users/madamek/Library/Python/3.9/lib/python/site-packages (1.21.0)
# Requirement already satisfied: matplotlib in /Users/madamek/Library/Python/3.9/lib/python/site-packages (3.4.2)
# Requirement already satisfied: seaborn in /Users/madamek/Library/Python/3.9/lib/python/site-packages (0.11.1)
# Requirement already satisfied: scipy in /Users/madamek/Library/Python/3.9/lib/python/site-packages (1.7.0)
# Requirement already satisfied: biosppy in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (0.7.3)
# Requirement already satisfied: hrv-analysis in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (1.0.4)
# Requirement already satisfied: py-ecg-detectors in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/madamek/Library/Python/3.9/lib/python/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/madamek/Library/Python/3.9/lib/python/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/madamek/Library/Python/3.9/lib/python/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: bidict in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from biosppy) (0.21.2)
# Requirement already satisfied: h5py in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from biosppy) (3.3.0)
# Requirement already satisfied: scikit-learn in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from biosppy) (0.24.2)
# Requirement already satisfied: shortuuid in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from biosppy) (1.0.1)
# Requirement already satisfied: joblib in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from biosppy) (1.0.1)
# Requirement already satisfied: opencv-python in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from biosppy) (4.5.3.56)
# Requirement already satisfied: astropy>=3.0.4 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from hrv-analysis) (4.3.1)
# Requirement already satisfied: nolds>=0.4.1 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from hrv-analysis) (0.5.2)
# Requirement already satisfied: pyerfa>=1.7.3 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from astropy>=3.0.4->hrv-analysis) (2.0.0)
# Requirement already satisfied: setuptools in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from nolds>=0.4.1->hrv-analysis) (57.0.0)
# Requirement already satisfied: future in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from nolds>=0.4.1->hrv-analysis) (0.18.2)
# Requirement already satisfied: pywavelets in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from py-ecg-detectors) (1.1.1)
# Requirement already satisfied: gatspy in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from py-ecg-detectors) (0.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/Cellar/jupyterlab/3.1.6/libexec/lib/python3.9/site-packages (from scikit-learn->biosppy) (2.2.0)
# WARNING: You are using pip version 21.1.3; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/local/Cellar/jupyterlab/3.1.6/libexec/bin/python3.9 -m pip install --upgrade pip' command.

# %%
#@title Importing Modules
# system imports
import os
#import sys

# data science
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Ellipse
import seaborn as sns

# signal processing 
from scipy import signal
from scipy.ndimage import label
from scipy.stats import zscore
from scipy.interpolate import interp1d
from scipy.integrate import trapz

# bio signal processing 
from hrvanalysis import remove_outliers, remove_ectopic_beats, interpolate_nan_values,get_time_domain_features
from ecgdetectors import Detectors

# misc
import warnings
import glob
from datetime import timedelta
import csv

# %%
#@title Loading vitaldb stuff
# %load vitaldb
import gzip
from scipy import signal
import numpy as np
import pandas as pd
import datetime
from struct import pack, unpack_from, Struct

unpack_b = Struct('<b').unpack_from
unpack_w = Struct('<H').unpack_from
unpack_s = Struct('<h').unpack_from
unpack_f = Struct('<f').unpack_from
unpack_d = Struct('<d').unpack_from
unpack_dw = Struct('<L').unpack_from
pack_b = Struct('<b').pack
pack_w = Struct('<H').pack
pack_s = Struct('<h').pack
pack_f = Struct('<f').pack
pack_d = Struct('<d').pack
pack_dw = Struct('<L').pack


def unpack_str(buf, pos):
    strlen = unpack_dw(buf, pos)[0]
    pos += 4
    val = buf[pos:pos + strlen].decode('utf-8', 'ignore')
    pos += strlen
    return val, pos


def pack_str(s):
    sutf = s.encode('utf-8')
    return pack_dw(len(sutf)) + sutf


# 4 byte L (unsigned) l (signed)
# 2 byte H (unsigned) h (signed)
# 1 byte B (unsigned) b (signed)
def parse_fmt(fmt):
    if fmt == 1:
        return 'f', 4
    elif fmt == 2:
        return 'd', 8
    elif fmt == 3:
        return 'b', 1
    elif fmt == 4:
        return 'B', 1
    elif fmt == 5:
        return 'h', 2
    elif fmt == 6:
        return 'H', 2
    elif fmt == 7:
        return 'l', 4
    elif fmt == 8:
        return 'L', 4
    return '', 0


class VitalFile:
    def __init__(self, ipath, dtnames=None):
        self.load_vital(ipath, dtnames)

    def get_samples(self, dtname, interval=1):
        if not interval:
            return None

        trk = self.find_track(dtname)
        if not trk:
            return None

        # 리턴 할 길이
        nret = int(np.ceil((self.dtend - self.dtstart) / interval))

        if trk['type'] == 2:  # numeric track
            ret = np.full(nret, np.nan)  # create a dense array
            for rec in trk['recs']:  # copy values
                idx = int((rec['dt'] - self.dtstart) / interval)
                if idx < 0:
                    idx = 0
                elif idx > nret:
                    idx = nret
                ret[idx] = rec['val']
            return ret
        elif trk['type'] == 1:  # wave track
            srate = trk['srate']
            recs = trk['recs']

            # 자신의 srate 만큼 공간을 미리 확보
            nsamp = int(np.ceil((self.dtend - self.dtstart) * srate))
            ret = np.full(nsamp, np.nan)

            # 실제 샘플을 가져와 채움
            for rec in recs:
                sidx = int(np.ceil((rec['dt'] - self.dtstart) * srate))
                eidx = sidx + len(rec['val'])
                srecidx = 0
                erecidx = len(rec['val'])
                if sidx < 0:  # self.dtstart 이전이면
                    srecidx -= sidx
                    sidx = 0
                if eidx > nsamp:  # self.dtend 이후이면
                    erecidx -= (eidx - nsamp)
                    eidx = nsamp
                ret[sidx:eidx] = rec['val'][srecidx:erecidx]

            # gain offset 변환
            if trk['fmt'] > 2:  # 1: float, 2: double
                ret *= trk['gain']
                ret += trk['offset']

            # 리샘플 변환
            if srate != int(1 / interval + 0.5):
                ret = np.take(ret, np.linspace(0, nsamp - 1, nret).astype(np.int64))

            return ret

        return None

    def find_track(self, dtname):
        dname = None
        tname = dtname
        if dtname.find('/') != -1:
            dname, tname = dtname.split('/')

        for trk in self.trks.values():  # find track
            if trk['name'] == tname:
                did = trk['did']
                if did == 0 or not dname:
                    return trk                    
                if did in self.devs:
                    dev = self.devs[did]
                    if 'name' in dev and dname == dev['name']:
                        return trk

        return None

    def save_vital(self, ipath, compresslevel=1):
        f = gzip.GzipFile(ipath, 'wb', compresslevel=compresslevel)

        # save header
        if not f.write(b'VITA'):  # check sign
            return False
        if not f.write(pack_dw(3)):  # version
            return False
        if not f.write(pack_w(10)):  # header len
            return False
        if not f.write(self.header):  # save header
            return False

        # save devinfos
        for did, dev in self.devs.items():
            if did == 0: continue
            ddata = pack_dw(did) + pack_str(dev['name']) + pack_str(dev['type']) + pack_str(dev['port'])
            if not f.write(pack_b(9) + pack_dw(len(ddata)) + ddata):
                return False

        # save trkinfos
        for tid, trk in self.trks.items():
            ti = pack_w(tid) + pack_b(trk['type']) + pack_b(trk['fmt']) + pack_str(trk['name']) \
                + pack_str(trk['unit']) + pack_f(trk['mindisp']) + pack_f(trk['maxdisp']) \
                + pack_dw(trk['col']) + pack_f(trk['srate']) + pack_d(trk['gain']) + pack_d(trk['offset']) \
                + pack_b(trk['montype']) + pack_dw(trk['did'])
            if not f.write(pack_b(0) + pack_dw(len(ti)) + ti):
                return False

            # save recs
            for rec in trk['recs']:
                rdata = pack_w(10) + pack_d(rec['dt']) + pack_w(tid)  # infolen + dt + tid (= 12 bytes)
                if trk['type'] == 1:  # wav
                    rdata += pack_dw(len(rec['val'])) + rec['val'].tobytes()
                elif trk['type'] == 2:  # num
                    fmtcode, fmtlen = parse_fmt(trk['fmt'])
                    rdata += pack(fmtcode, rec['val'])
                elif trk['type'] == 5:  # str
                    rdata += pack_dw(0) + pack_str(rec['val'])

                if not f.write(pack_b(1) + pack_dw(len(rdata)) + rdata):
                    return False

        # save trk order
        if hasattr(self, 'trkorder'):
            cdata = pack_b(5) + pack_w(len(self.trkorder)) + self.trkorder.tobytes()
            if not f.write(pack_b(6) + pack_dw(len(cdata)) + cdata):
                return False

        f.close()
        return True

    def load_vital(self, ipath, dtnames=None):
        if isinstance(dtnames, str):
            if dtnames.find(','):
                dtnames = dtnames.split(',')
            else:
                dtnames = [dtnames]

        # dtnames: 로딩을 원하는 dtname 의 리스트. dtnames가 None 이면 트랙 목록만 읽혀짐
        f = gzip.GzipFile(ipath, 'rb')

        # parse header
        if f.read(4) != b'VITA':  # check sign
            return False

        f.read(4)  # file version

        buf = f.read(2)
        if buf == b'':
            return False

        headerlen = unpack_w(buf, 0)[0]
        self.header = f.read(headerlen)  # skip header
        self.dgmt = unpack_s(self.header, 0)[0]  # ut - dgmt = localtime

        # parse body
        self.devs = {0: {}}  # device names. did = 0 represents the vital recorder
        self.trks = {}
        self.dtstart = 0
        self.dtend = 0

        try:
            sel_tids = set()
            while True:
                buf = f.read(5)
                if buf == b'':
                    break
                pos = 0

                packet_type = unpack_b(buf, pos)[0]; pos += 1
                packet_len = unpack_dw(buf, pos)[0]; pos += 4

                buf = f.read(packet_len)
                if buf == b'':
                    break
                pos = 0

                if packet_type == 9:  # devinfo
                    did = unpack_dw(buf, pos)[0]; pos += 4
                    devtype, pos = unpack_str(buf, pos)
                    name, pos = unpack_str(buf, pos)
                    if len(buf) > pos + 4:  # port는 없을 수 있다
                        port, pos = unpack_str(buf, pos)
                    if not name:
                        name = devtype
                    self.devs[did] = {'name': name, 'type': devtype, 'port': port}
                elif packet_type == 0:  # trkinfo
                    did = col = 0
                    montype = unit = ''
                    gain = offset = srate = mindisp = maxdisp = 0.0
                    tid = unpack_w(buf, pos)[0]; pos += 2
                    trktype = unpack_b(buf, pos)[0]; pos += 1
                    fmt = unpack_b(buf, pos)[0]; pos += 1
                    tname, pos = unpack_str(buf, pos)

                    if packet_len > pos:
                        unit, pos = unpack_str(buf, pos)
                    if packet_len > pos:
                        mindisp = unpack_f(buf, pos)[0]
                        pos += 4
                    if packet_len > pos:
                        maxdisp = unpack_f(buf, pos)[0]
                        pos += 4
                    if packet_len > pos:
                        col = unpack_dw(buf, pos)[0]
                        pos += 4
                    if packet_len > pos:
                        srate = unpack_f(buf, pos)[0]
                        pos += 4
                    if packet_len > pos:
                        gain = unpack_d(buf, pos)[0]
                        pos += 8
                    if packet_len > pos:
                        offset = unpack_d(buf, pos)[0]
                        pos += 8
                    if packet_len > pos:
                        montype = unpack_b(buf, pos)[0]
                        pos += 1
                    if packet_len > pos:
                        did = unpack_dw(buf, pos)[0]
                        pos += 4

                    dname = ''
                    if did and did in self.devs:
                        if did and did in self.devs:
                            dname = self.devs[did]['name']
                        dtname = dname + '/' + tname
                    else:
                        dtname = tname

                    if dtnames:  # 사용자가 특정 트랙만 읽으라고 했을 때
                        matched = False
                        if dtname in dtnames:  # dtname (현재 읽고 있는 트랙명)이 dtnames에 지정된 것과 정확히 일치할 때
                            matched = True
                        else:
                            for sel_dtname in dtnames:
                                if dtname.endswith('/' + sel_dtname) or (dname + '/*' == sel_dtname): # 트랙명만 지정 or 특정 장비의 모든 트랙일 때
                                    matched = True
                                    sel_tids.add(tid)
                                    break
                                    
                        if not matched:
                            continue
                        sel_tids.add(tid)  # 앞으로는 sel_tids 에서 체크한다

                    # dtnames가 None 이거나 사용자가 원하는 sel 일 때
                    self.trks[tid] = {'name': tname, 'dtname': dtname, 'type': trktype, 'fmt': fmt, 'unit': unit, 'srate': srate,
                                      'mindisp': mindisp, 'maxdisp': maxdisp, 'col': col, 'montype': montype,
                                      'gain': gain, 'offset': offset, 'did': did, 'recs': []}
                elif packet_type == 1:  # rec
                    infolen = unpack_w(buf, pos)[0]; pos += 2
                    dt = unpack_d(buf, pos)[0]; pos += 8
                    tid = unpack_w(buf, pos)[0]; pos += 2
                    pos = 2 + infolen

                    if self.dtstart == 0 or dt < self.dtstart:
                        self.dtstart = dt
                    
                    # TODO: dtrec end 는 다를 수 있음 wav 읽어서 nsamp 로딩해야함
                    if dt > self.dtend:
                        self.dtend = dt

                   # if not dtnames:  # dtnames 가 None 이면 트랙 목록만 읽혀짐
                    #    continue

                    if tid not in self.trks:  # 이전 정보가 없는 트랙이거나
                        continue
                 #   if tid not in sel_tids:  # 사용자가 트랙 지정을 한 경우
                 #       continue

                    trk = self.trks[tid]  

                    fmtlen = 4
                    # gain, offset 변환은 하지 않은 raw data 상태로만 로딩한다.
                    # 항상 이 변환이 필요하지 않기 때문에 변환은 get_samples 에서 나중에 한다.
                    if trk['type'] == 1:  # wav
                        fmtcode, fmtlen = parse_fmt(trk['fmt'])
                        nsamp = unpack_dw(buf, pos)[0]; pos += 4
                        samps = np.ndarray((nsamp,), buffer=buf, offset=pos, dtype=np.dtype(fmtcode)); pos += nsamp * fmtlen
                        trk['recs'].append({'dt': dt, 'val': samps})
                    elif trk['type'] == 2:  # num
                        fmtcode, fmtlen = parse_fmt(trk['fmt'])
                        val = unpack_from(fmtcode, buf, pos)[0]; pos += fmtlen
                        trk['recs'].append({'dt': dt, 'val': val})
                    elif trk['type'] == 5:  # str
                        pos += 4  # skip
                        s, pos = unpack_str(buf, pos)
                        trk['recs'].append({'dt': dt, 'val': s})
                elif packet_type == 6:  # cmd
                    cmd = unpack_b(buf, pos)[0]; pos += 1
                    if cmd == 6:  # reset events
                        evt_trk = self.find_track('/EVENT')
                        if evt_trk:
                            evt_trk['recs'] = []
                    elif cmd == 5:  # trk order
                        cnt = unpack_w(buf, pos)[0]; pos += 2
                        self.trkorder = np.ndarray((cnt,), buffer=buf, offset=pos, dtype=np.dtype('H')); pos += cnt * 2

        except EOFError as error:
            print(error)
            pass

        # sorting tracks
        # for trk in self.trks.values():
        #     trk['recs'].sort(key=lambda r:r['dt'])

        f.close()
        return True


def load_trk(tid, interval=1):
    try:
        url = 'https://api.vitaldb.net/' + tid
        dtvals = pd.read_csv(url, na_values='-nan(ind)').values
    except:
        return np.empty(0)

    if len(dtvals) == 0:
        return np.empty(0)
    
    dtvals[:,0] /= interval  # convert time to row
    nsamp = int(np.nanmax(dtvals[:,0])) + 1  # find maximum index (array length)
    ret = np.full(nsamp, np.nan)  # create a dense array
    
    if np.isnan(dtvals[:,0]).any():  # wave track
        if nsamp != len(dtvals):  # resample
            ret = np.take(dtvals[:,1], np.linspace(0, len(dtvals) - 1, nsamp).astype(np.int64))
        else:
            ret = dtvals[:,1]
    else:  # numeric track
        for idx, val in dtvals:  # copy values
            ret[int(idx)] = val

    return ret


def load_trks(tids, interval=1):
    trks = []
    maxlen = 0
    for tid in tids:
        trk = load_trk(tid, interval)
        trks.append(trk)
        if len(trk) > maxlen:
            maxlen = len(trk)
    if maxlen == 0:
        return np.empty(0)
    ret = np.full((maxlen, len(tids)), np.nan)  # create a dense array
    for i in range(len(tids)):  # copy values
        ret[:len(trks[i]), i] = trks[i]
    return ret

def vital_recs(ipath, dtnames, interval=0.3, return_timestamp=False, return_datetime=False):
    if not dtnames:
        return []

    # 만일 SNUADC/ECG_II,Solar8000 형태의 문자열이면?
    if isinstance(dtnames, str):
        if dtnames.find(',') != -1:
            dtnames = dtnames.split(',')
        else:
            dtnames = [dtnames]

    vf = VitalFile(ipath, dtnames)

    nrows = int(np.ceil((vf.dtend - vf.dtstart) / interval))
    if not nrows:
        return []

    ret = []
    for dtname in dtnames:
        col = vf.get_samples(dtname, interval)
        if col is None:
            col = np.full(nrows, np.nan)
        ret.append(col)
    if not ret:
        return []

    # return time column
    if return_datetime: # in this case, numpy array with object type will be returned
        tzi = datetime.timezone(datetime.timedelta(minutes=-vf.dgmt))
        dts = datetime.datetime.fromtimestamp(vf.dtstart, tzi)
        dte = dts + datetime.timedelta(seconds=len(ret[0]))
        ret.insert(0, [dts + datetime.timedelta(seconds=i*interval) for i in range(len(ret[0]))])
    elif return_timestamp:
        ret.insert(0, np.arange(vf.dtstart, vf.dtend, interval))

    ret = np.transpose(ret)

    return ret

def vital_trks(ipath):
    # 트랙 목록만 읽어옴
    ret = []
    vf = VitalFile(ipath)
    for trk in vf.trks.values():
        tname = trk['name']
        dname = ''
        did = trk['did']
        if did in vf.devs:
            dev = vf.devs[did]
            if 'name' in dev:
                dname = dev['name']
        ret.append(dname + '/' + tname)
    return ret


# api files
dftrks = None

def load_case(tnames, caseid=None, interval=1):
    global dftrks

    if not caseid:
        return None
    if dftrks is None:
        dftrks = pd.read_csv("https://api.vitaldb.net/trks")

    tids = []
    for tname in tnames:
        tid = dftrks[(dftrks['caseid'] == caseid) & (dftrks['tname'] == tname)]['tid'].values[0]
        tids.append(tid)
    
    return load_trks(tids, interval)


def load_cases(tnames, caseids=None, interval=1, maxcases=1):
    global dftrks

    # find the caseids which contains tnames
    if not isinstance(tnames, list):
        if isinstance(tnames, str):
            tnames = tnames.split(',')
        else:
            return None

    if interval == 0:
        return None

    if not caseids:
        if dftrks is None:
            dftrks = pd.read_csv("https://api.vitaldb.net/trks")

        # filter cases which don't have all tnames
        caseids = None
        for tname in tnames:
            matched = set(dftrks[dftrks['tname'] == tname]['caseid'])
            if caseids is None:
                caseids = matched
            else:
                caseids = caseids & matched
        
    cases = {}
    for caseid in caseids:
        case = load_case(tnames, caseid, interval)
        if case is None:
            continue
        if len(case) == 0:
            continue
        cases[caseid] = case
        if len(cases) >= maxcases:
            break

    return cases

# %%
#@title class that contains our vital data for future use
from scipy import ndimage
class VitalDBData:
    def __init__(self,vital_file):
        vital_data = VitalFile(vital_file)
        ecg_settings = vital_data.find_track('ECG_I')
        
        self.sampling_rate = ecg_settings['srate']
        self.ecg_I = vital_data.get_samples('ECG_I', 1/self.sampling_rate)
        self.ecg_II = vital_data.get_samples('ECG_II', 1/self.sampling_rate)
        self.ecg_III = vital_data.get_samples('ECG_III', 1/self.sampling_rate)
        self.starttime = datetime.datetime.fromtimestamp(vital_data.dtstart)
        self.endtime = datetime.datetime.fromtimestamp(vital_data.dtend)

        self.__removeNaNs()
        
    def __removeNaNs(self):
        nan_time = np.isnan(self.ecg_I)
        self.ecg_I[nan_time]=0
        self.ecg_II[nan_time]=0
        self.ecg_III[nan_time]=0
        print("Removing data:" )
        print(timedelta(seconds= np.sum(nan_time)/self.sampling_rate))
        self.starttime=self.starttime+timedelta(seconds= np.sum(nan_time)/self.sampling_rate)
        self.t=np.arange(len(self.ecg_I))/(self.sampling_rate)

# %%
#test extraction
test_path='/Users/madamek/Box/taVNS_clinical/2020004/210222/HR18829_210222_081916.vital'
vital_data = VitalDBData(test_path)
t_peaks=[];
time_peaks=[];
nn_intervals_subject=[]
if vital_data.ecg_I is not None:
    detectors = Detectors(vital_data.sampling_rate)
    rpeaks = detectors.two_average_detector(vital_data.ecg_I)
    
    t_peaks=vital_data.t[rpeaks];
    for i in range(len(t_peaks)):
        time_peaks.append(vital_data.starttime+timedelta(seconds=t_peaks[i]))
    # group peaks so we get a single peak per beat (hopefully)
    # grouped_peaks = group_peaks(peaks,10)
    rr_intervals = np.diff(rpeaks)
    time_peaks=time_peaks[:-1]; #remove last item - since diff is a difference
    rr_intervals = rr_intervals*1e3/vital_data.sampling_rate # convert to ms
    rr_intervals_without_outliers = remove_outliers(rr_intervals=rr_intervals)

    interpolated_rr_intervals = interpolate_nan_values(rr_intervals=rr_intervals_without_outliers,interpolation_method="linear")
    nn_intervals_list = remove_ectopic_beats(rr_intervals=interpolated_rr_intervals, method="malik")
    interpolated_nn_intervals = interpolate_nan_values(rr_intervals=nn_intervals_list)
    nn_intervals_subject.extend(interpolated_nn_intervals)
    print('Array size for subject: ' + str(len(nn_intervals_subject)) + ' ' + str(len(time_peaks)))
# Out:
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:02:18.434000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2832.0]
# 1320 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 3548 3548

# %%
search_dir = '/Users/madamek/Box/taVNS_clinical'
vit_subject_dir= os.listdir(search_dir)

for i,subj in enumerate(vit_subject_dir): 
    if not subj.isnumeric():
        continue
    time_peaks_subject=[];    
    nn_intervals_subject=[];
    vit_files_dir = os.listdir(os.path.join(search_dir,subj))
    print(subj)
    if(os.path.exists(os.path.join(search_dir,subj, subj+'.csv'))):
       print('Subject data already available, skipping')
       continue
    for vit_dir in vit_files_dir:
        vit_files=os.scandir(os.path.join(search_dir,subj,vit_dir))
        for j,vital_filename in enumerate(vit_files):
            if not vital_filename.name.endswith('.vital'):
                continue
            vital_file = os.path.join(search_dir,subj,vit_dir,vital_filename)
            print('Loading: '+vital_file)

            try:
                vital_data = VitalDBData(vital_file)
                time_peaks=[]
                if vital_data.ecg_I is not None:
                    detectors = Detectors(vital_data.sampling_rate)
                    rpeaks = detectors.two_average_detector(vital_data.ecg_I)
                    t_peaks=vital_data.t[rpeaks];
                    for i in range(len(t_peaks)):
                        time_peaks.append(vital_data.starttime+timedelta(seconds=t_peaks[i]))
                    time_peaks=time_peaks[:-1];
                    # group peaks so we get a single peak per beat (hopefully)
                    # grouped_peaks = group_peaks(peaks,10)
                    rr_intervals = np.diff(rpeaks)
                    rr_intervals = rr_intervals*1e3/vital_data.sampling_rate # convert to ms
                    rr_intervals_without_outliers = remove_outliers(rr_intervals=rr_intervals)

                    interpolated_rr_intervals = interpolate_nan_values(rr_intervals=rr_intervals_without_outliers,interpolation_method="linear")
                    nn_intervals_list = remove_ectopic_beats(rr_intervals=interpolated_rr_intervals, method="malik")
                    interpolated_nn_intervals = interpolate_nan_values(rr_intervals=nn_intervals_list)                 
                    nn_intervals_subject.extend(interpolated_nn_intervals)
                    time_peaks_subject.extend(time_peaks)
                    print('Array size for subject: ' + str(len(nn_intervals_subject)) + ' ' + str(len(time_peaks_subject)))
            except Exception as e: 
                print('error during Vital data' + repr(e))
                pass
            
    d = {'timestamp': time_peaks_subject, 'nn_interval': nn_intervals_subject}
    df = pd.DataFrame(data=d)
    df.to_csv(os.path.join(search_dir,subj, subj+'.csv'))
    df.to_pickle(os.path.join(search_dir,subj, subj+'.pickle'))
# Out:
# 2020004
# Subject data already available, skipping
# 2020005
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_143100.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_143621.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_171516.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_171637.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_171639.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_171752.vital
# Removing data:
# 0:25:40.050000
# 0 outlier(s) have been deleted.
# 43 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1449 1449
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_180000.vital
# Removing data:
# 0:00:11.082000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6698.0]
# 55 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 6845 6845
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_190001.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4826.0]
# 14 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 12488 12488
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_200000.vital
# Removing data:
# 0:00:14.138000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8990.0]
# 21 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 18161 18161
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_210001.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3118.0]
# 30 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 23921 23921
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_220001.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3158.0]
# 15 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 29513 29513
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210329/HR18826_210329_230001.vital
# Removing data:
# 0:00:10.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6704.0]
# 33 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 35310 35310
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_000001.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.482000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5016.0]
# 0 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 35690 35690
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_070644.vital
# Removing data:
# 0:01:57.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [42520.0]
# 37 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 40393 40393
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_080000.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_080716.vital
# Removing data:
# 0:21:51.850000
# 3 outlier(s) have been deleted.
# The outlier(s) value(s) are : [42278.0, 3386.0, 210234.0]
# 302 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 43264 43264
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_090001.vital
# Removing data:
# 0:00:08.578000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4248.0]
# 25 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 48832 48832
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_100001.vital
# Removing data:
# 0:00:09.090000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4466.0]
# 46 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 54204 54204
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_110001.vital
# Removing data:
# 0:00:14.210000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8536.0]
# 52 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 59884 59884
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_120000.vital
# Removing data:
# 0:00:08.706000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4354.0]
# 22 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 65494 65494
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_130001.vital
# Removing data:
# 0:00:14.210000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8632.0]
# 51 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 71463 71463
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_140001.vital
# Removing data:
# 0:00:09.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4772.0]
# 13 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 77346 77346
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_150000.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4786.0]
# 13 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 83353 83353
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_160000.vital
# Removing data:
# 0:00:13.954000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [9812.0]
# 34 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 89211 89211
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_170000.vital
# Removing data:
# 0:00:09.034000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5240.0]
# 26 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 95081 95081
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_180000.vital
# Removing data:
# 0:00:08.778000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5256.0]
# 41 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 100850 100850
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_190000.vital
# Removing data:
# 0:00:11.138000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6120.0]
# 16 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 106620 106620
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_200000.vital
# Removing data:
# 0:00:08.578000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4258.0]
# 29 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 112122 112122
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_210000.vital
# Removing data:
# 0:00:13.954000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7998.0]
# 63 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 117686 117686
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_220000.vital
# Removing data:
# 0:00:08.834000
# 6 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3812.0, 3412.0, 2962.0, 242684.0, 2874.0, 3254.0]
# 143 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 122826 122826
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210330/HR18826_210330_230000.vital
# Removing data:
# 0:00:08.834000
# 8 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4796.0, 3444.0, 3202.0, 3268.0, 3390.0, 3596.0, 3292.0, 2866.0]
# 422 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 128199 128199
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_000000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.932000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7012.0, 4242.0, 3394.0, 3174.0]
# 129 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 129818 129818
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_074143.vital
# Removing data:
# 0:00:06.274000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2740.0, 1078172.0]
# 3 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 129827 129827
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_080000.vital
# Removing data:
# 0:00:08.834000
# 6 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2740.0, 4702.0, 2740.0, 2386182.0, 3838.0, 17608.0]
# 27 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 131452 131452
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_090000.vital
# Removing data:
# 0:00:08.962000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4922.0]
# 69 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 136561 136561
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_100001.vital
# Removing data:
# 0:00:08.834000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4730.0, 2698.0]
# 62 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 141650 141650
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_110001.vital
# Removing data:
# 0:11:30.818000
# 5 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5218.0, 2444.0, 42256.0, 3114.0, 12690.0]
# 364 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 146490 146490
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_120001.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.818000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7624.0, 3570.0]
# 85 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 148637 148637
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_160746.vital
# Removing data:
# 0:00:07.506000
# 0 outlier(s) have been deleted.
# 63 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 152871 152871
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_170000.vital
# Removing data:
# 0:00:10.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6804.0]
# 57 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 157466 157466
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_180000.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4656.0]
# 91 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 162106 162106
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_190000.vital
# Removing data:
# 0:00:13.954000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [10428.0]
# 66 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 166853 166853
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_200000.vital
# Removing data:
# 0:00:09.602000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5858.0]
# 67 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 171786 171786
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_210000.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3506.0]
# 55 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 176847 176847
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_220000.vital
# Removing data:
# 0:00:10.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5544.0]
# 124 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 181505 181505
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210331/HR18826_210331_230000.vital
# Removing data:
# 0:00:09.090000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3336.0, 2808.0, 3120.0, 37916.0]
# 87 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 185896 185896
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_000000.vital
# Removing data:
# 0:00:10.882000
# 3 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6442.0, 3282.0, 5568.0]
# 88 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 190334 190334
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_010000.vital
# Removing data:
# 0:00:09.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4532.0]
# 19 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 194951 194951
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_020000.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3864.0]
# 123 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 199498 199498
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_030000.vital
# Removing data:
# 0:00:10.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6386.0]
# 415 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 204147 204147
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_040000 (adamek.m@wustl.edu 2).vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5198.0]
# 74 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 208689 208689
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_040000 (adamek.m@wustl.edu).vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.186000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5198.0]
# 58 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 210838 210838
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_040000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.954000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5198.0]
# 56 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 212694 212694
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_050000 (adamek.m@wustl.edu 2).vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.770000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6568.0]
# 130 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 214969 214969
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_050000 (adamek.m@wustl.edu 3).vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:10.330000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6568.0]
# 132 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 218422 218422
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_050000 (adamek.m@wustl.edu).vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.522000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6568.0]
# 79 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 219658 219658
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_050000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.444000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6568.0]
# 24 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 220128 220128
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_082723.vital
# Removing data:
# 0:00:08.626000
# 0 outlier(s) have been deleted.
# 14 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 222368 222368
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_090000.vital
# Removing data:
# 0:09:32.546000
# 3 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4994.0, 2400.0, 42266.0]
# 2253 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 228663 228663
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_100000.vital
# Removing data:
# 0:04:39.938000
# 6 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6660.0, 42488.0, 8818.0, 42260.0, 135622.0, 30102.0]
# 1810 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 234150 234150
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_110000.vital
# Removing data:
# 0:00:08.634000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4456.0]
# 43 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 238490 238490
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_120000.vital
# Removing data:
# 0:00:09.034000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4730.0]
# 63 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 242869 242869
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_130000.vital
# Removing data:
# 0:00:10.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7126.0]
# 12 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 247252 247252
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_140000.vital
# Removing data:
# 0:06:52.802000
# 7 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3558.0, 3188.0, 3448.0, 2262.0, 42464.0, 332216.0, 30434.0]
# 179 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 251442 251442
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_150000.vital
# Removing data:
# 0:00:09.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5900.0]
# 90 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 256200 256200
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_160000.vital
# Removing data:
# 0:04:53.506000
# 5 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5308.0, 42676.0, 220864.0, 10024.0, 3744.0]
# 61 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 260645 260645
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_170000.vital
# Removing data:
# 0:00:13.036000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8720.0]
# 3 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 260768 260768
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_170305.vital
# Removing data:
# 0:00:09.130000
# 0 outlier(s) have been deleted.
# 26 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 265060 265060
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210401/HR18826_210401_180000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.314000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4662.0]
# 14 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 268486 268486
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_084913.vital
# Removing data:
# 0:00:06.266000
# 0 outlier(s) have been deleted.
# 4 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 269273 269273
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_090000.vital
# Removing data:
# 0:00:12.930000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [9260.0]
# 99 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 273858 273858
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_100000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.714000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5508.0]
# 24 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 278324 278324
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_110001.vital
# Removing data:
# 0:00:16.714000
# 0 outlier(s) have been deleted.
# 310 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 283033 283033
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_120001.vital
# Removing data:
# 0:00:12.836000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8290.0]
# 272 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 287641 287641
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_130001.vital
# Removing data:
# 0:00:09.146000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4662.0]
# 241 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 292227 292227
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_140000.vital
# Removing data:
# 0:00:35.770000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [30570.0]
# 133 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 296605 296605
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_150000.vital
# Removing data:
# 0:00:10.938000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6210.0]
# 215 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 301181 301181
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_160000.vital
# Removing data:
# 0:00:08.890000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3678.0]
# 152 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 305861 305861
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_170000.vital
# Removing data:
# 0:14:07.290000
# 5 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7284.0, 41782.0, 785338.0, 2740.0, 44588.0]
# 67 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 309534 309534
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210402/HR18826_210402_180000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.006000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6460.0]
# 5 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 309822 309822
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_090056.vital
# Removing data:
# 0:05:25.770000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2646.0, 42104.0]
# 222 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 313588 313588
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_100000.vital
# Removing data:
# 0:00:09.034000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5246.0]
# 232 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 317249 317249
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_110000.vital
# Removing data:
# 0:00:13.954000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [10050.0]
# 202 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 320674 320674
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_120000.vital
# Removing data:
# 0:00:09.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6256.0]
# 1981 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 326049 326049
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_130000.vital
# Removing data:
# 0:00:08.834000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5262.0, 3454.0, 238312.0, 3122.0]
# 282 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 329496 329496
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_140000.vital
# Removing data:
# 0:00:10.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7348.0]
# 1393 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 334052 334052
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_150000.vital
# Removing data:
# 0:00:08.834000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4802.0, 2944.0]
# 1724 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 339048 339048
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_160000.vital
# Removing data:
# 0:00:14.154000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [9526.0]
# 397 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 343298 343298
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_170000.vital
# Removing data:
# 0:00:08.834000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3510.0, 249334.0]
# 195 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 347427 347427
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_180000.vital
# Removing data:
# 0:00:09.090000
# 3 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4710.0, 3210.0, 32832.0]
# 86 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 351652 351652
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_190000.vital
# Removing data:
# 0:00:11.138000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5930.0, 3490.0]
# 380 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 356069 356069
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210403/HR18826_210403_200000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.138000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3582.0]
# 9 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 357529 357529
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_100000.vital
# Removing data:
# 0:00:09.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4308.0]
# 388 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 361115 361115
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_110000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.386000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4072.0]
# 311 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 363567 363567
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_195222.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:06.018000
# 0 outlier(s) have been deleted.
# 70 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 364092 364092
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_200000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.682000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4240.0]
# 221 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 365870 365870
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_210920.vital
# Removing data:
# 0:00:08.714000
# 0 outlier(s) have been deleted.
# 248 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 369869 369869
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_220001.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4992.0]
# 86 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 374868 374868
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210404/HR18826_210404_230001.vital
# Removing data:
# 0:00:08.834000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4600.0]
# 65 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 379593 379593
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_000000.vital
# Removing data:
# 0:00:09.090000
# 0 outlier(s) have been deleted.
# 55 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 384208 384208
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_010000.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.242000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4796.0]
# 7 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 384355 384355
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_075002.vital
# Removing data:
# 0:00:06.330000
# 0 outlier(s) have been deleted.
# 17 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 385060 385060
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_080000.vital
# Removing data:
# 0:00:11.122000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7956.0]
# 67 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 386628 386628
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_082128.vital
# Removing data:
# 0:00:07.306000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4852.0]
# 9 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 386830 386830
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_082526.vital
# Removing data:
# 1:21:54.812000
# 7 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3712.0, 2914754.0, 2702.0, 2959508.0, 3224.0, 55616.0, 42306.0]
# 2322 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 395760 395760
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_115804.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_120045.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_121035.vital
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_121505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:36:14.874000
# 0 outlier(s) have been deleted.
# 112 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 397407 397407
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_131505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.602000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5446.0]
# 152 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 401720 401720
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_141505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.226000
# 0 outlier(s) have been deleted.
# 187 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 406290 406290
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_151505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.914000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5298.0]
# 176 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 410835 410835
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_161505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.058000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4914.0, 3208.0, 3408.0, 160676.0]
# 120 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 415389 415389
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_171505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.730000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7940.0]
# 21 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 420636 420636
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_181505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.058000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4876.0]
# 4 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 425937 425937
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_191505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:15.202000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [11032.0]
# 7 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 431044 431044
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_201505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.458000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5984.0]
# 18 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 436070 436070
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_211505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.914000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3414.0]
# 16 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 441191 441191
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_221505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.842000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6482.0]
# 20 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 446260 446260
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210405/HR18826_210405_231505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.234000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3150.0]
# 12 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 451462 451462
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_001505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.242000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6938.0]
# 7 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 456853 456853
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_011505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.746000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3554.0]
# 15 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 462282 462282
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_021505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.970000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4900.0]
# 7 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 467647 467647
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_031505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.074000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6838.0]
# 22 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 473123 473123
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_041505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.882000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4888.0]
# 10 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 478698 478698
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_051505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.674000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7048.0]
# 10 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 484410 484410
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_061505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.058000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4278.0]
# 18 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 489611 489611
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_071505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4458.0]
# 15 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 494848 494848
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_081505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:10:57.194000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8220.0, 2774.0, 42512.0, 595824.0]
# 27 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 499206 499206
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_091505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:26:20.386000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5558.0, 2478.0, 42222.0, 1521934.0]
# 18 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 502117 502117
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_101505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.042000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6662.0]
# 23 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 507167 507167
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_111505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4024.0]
# 52 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 512447 512447
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_121505.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:33.474000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [30322.0]
# 20 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 516244 516244
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210406/HR18826_210406_160045.vital
# Compressed file ended before the end-of-stream marker was reached
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_065247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.010000
# 0 outlier(s) have been deleted.
# 56 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 520741 520741
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_075247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.072000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4746.0]
# 77 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 525481 525481
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_085247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:21:36.226000
# 7 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3602.0, 3124.0, 42350.0, 1157820.0, 2796.0, 42558.0, 28430.0]
# 35 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 528430 528430
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_095247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.642000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7872.0]
# 58 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 533352 533352
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_105247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.546000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3534.0]
# 20 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 538214 538214
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_115247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:13.978000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [8444.0]
# 13 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 543235 543235
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_125247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.826000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4552.0]
# 22 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 548306 548306
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_135247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.058000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4084.0]
# 28 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 553417 553417
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_145247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:10.818000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5516.0]
# 31 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 558350 558350
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_155247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:17:53.362000
# 12 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4626.0, 2612.0, 42118.0, 2832.0, 42440.0, 183764.0, 2740.0, 62334.0, 2410.0, 42796.0, 50802.0, 2588.0]
# 359 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 562935 562935
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_165247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.258000
# 0 outlier(s) have been deleted.
# 122 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 567870 567870
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_175247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.714000
# 3 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4882.0, 3642.0, 3380.0]
# 109 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 572696 572696
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_185247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4964.0]
# 33 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 577459 577459
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_195247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:10.850000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6672.0]
# 54 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 582070 582070
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_205247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.858000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4502.0]
# 24 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 586398 586398
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_215247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:13.778000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [10252.0, 4190.0]
# 1474 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 590765 590765
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_225247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.570000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2740.0, 5648.0, 2740.0, 2386600.0]
# 80 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 592323 592323
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210407/HR18826_210407_235247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.658000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5018.0]
# 190 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 596532 596532
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_005247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:10.706000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6428.0]
# 36 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 600755 600755
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_015247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.392000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3864.0]
# 0 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 601517 601517
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_025247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.210000
# 0 outlier(s) have been deleted.
# 114 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 605933 605933
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_035247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.914000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4560.0]
# 75 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 610431 610431
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_045247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.802000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4550.0]
# 77 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 615244 615244
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_055247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.074000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7096.0]
# 65 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 620072 620072
# Loading: /Users/madamek/Box/taVNS_clinical/2020005/210408/HR18826_210408_065247.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.858000
# ...
# 0 outlier(s) have been deleted.
# 127 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1079236 1079236
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_014341.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.482000
# 0 outlier(s) have been deleted.
# 22 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1082909 1082909
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_024346.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.258000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3478.0]
# 5 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1086716 1086716
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_034351.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.418000
# 0 outlier(s) have been deleted.
# 3 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1090433 1090433
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_044356.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.298000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6476.0]
# 1 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1093918 1093918
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_054401.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.642000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6082.0]
# 57 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1097651 1097651
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_064406.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.490000
# 0 outlier(s) have been deleted.
# 1 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1101358 1101358
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_074411.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.394000
# 0 outlier(s) have been deleted.
# 6 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1102802 1102802
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_084416.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.682000
# 0 outlier(s) have been deleted.
# 13 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1106077 1106077
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_094421.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.434000
# 0 outlier(s) have been deleted.
# 16 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1110062 1110062
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_104426.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.746000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3070.0]
# 81 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1114349 1114349
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_114431.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:34.370000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [28670.0]
# 153 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1117877 1117877
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_124436.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:10.082000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4150.0]
# 15 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1121681 1121681
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_134441.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.162000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [4906.0]
# 43 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1125912 1125912
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_144446.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.930000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7844.0]
# 4 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1129419 1129419
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_154451.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.098000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [5850.0, 3028.0]
# 39 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1132834 1132834
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_164456.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.058000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3152.0]
# 162 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1136794 1136794
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_174501.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.714000
# 0 outlier(s) have been deleted.
# 32 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1140301 1140301
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_184506.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.154000
# 0 outlier(s) have been deleted.
# 0 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1141629 1141629
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_193203.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.458000
# 0 outlier(s) have been deleted.
# 55 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1145526 1145526
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_203208.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.370000
# 0 outlier(s) have been deleted.
# 114 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1149616 1149616
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_213213.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.482000
# 0 outlier(s) have been deleted.
# 104 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1153245 1153245
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_223218.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.482000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3228.0]
# 6 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1156440 1156440
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210928/HR18829_210928_233223.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.362000
# 0 outlier(s) have been deleted.
# 190 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1160119 1160119
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_003228.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.042000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6230.0]
# 102 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1164151 1164151
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_013233.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.098000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7352.0]
# 228 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1167808 1167808
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_023238.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.434000
# 0 outlier(s) have been deleted.
# 220 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1172164 1172164
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_033243.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.634000
# 0 outlier(s) have been deleted.
# 41 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1176021 1176021
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_043248.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.834000
# 0 outlier(s) have been deleted.
# 19 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1179519 1179519
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_053253.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.778000
# 0 outlier(s) have been deleted.
# 397 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1183322 1183322
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_063258.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.722000
# 0 outlier(s) have been deleted.
# 144 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1187720 1187720
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_073303.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:34.914000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [28752.0]
# 253 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1191866 1191866
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_083308.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.114000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3396.0]
# 323 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1196625 1196625
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_093313.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.986000
# 0 outlier(s) have been deleted.
# 491 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1201222 1201222
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_103318.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:20:03.466000
# 2 outlier(s) have been deleted.
# The outlier(s) value(s) are : [7980.0, 42404.0]
# 220 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1204032 1204032
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_113323.vital
# Compressed file ended before the end-of-stream marker was reached
# error during Vital dataTypeError("'NoneType' object is not subscriptable")
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_123328.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:43:28.594000
# 4 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2740.0, 99648.0, 2890.0, 2274.0]
# 103 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1205033 1205033
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_133333.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.122000
# 0 outlier(s) have been deleted.
# 177 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1210006 1210006
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_143338.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.058000
# 0 outlier(s) have been deleted.
# 93 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1215614 1215614
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_153343.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.058000
# 0 outlier(s) have been deleted.
# 119 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1220930 1220930
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_163348.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.258000
# 0 outlier(s) have been deleted.
# 687 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1224991 1224991
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_173353.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.426000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [3036.0]
# 647 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1229188 1229188
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_183358.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:11.162000
# 0 outlier(s) have been deleted.
# 412 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1233456 1233456
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_193403.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.754000
# 0 outlier(s) have been deleted.
# 761 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1237590 1237590
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_203408.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:12.130000
# 1 outlier(s) have been deleted.
# The outlier(s) value(s) are : [6808.0]
# 593 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1241522 1241522
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_213413.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.282000
# 0 outlier(s) have been deleted.
# 518 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1245474 1245474
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_223418.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.626000
# 0 outlier(s) have been deleted.
# 307 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1250107 1250107
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210929/HR18829_210929_233423.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:09.458000
# 3 outlier(s) have been deleted.
# The outlier(s) value(s) are : [2842.0, 15500.0, 3090.0]
# 206 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1254561 1254561
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210930/HR18829_210930_003428.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:07.834000
# 0 outlier(s) have been deleted.
# 61 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1259240 1259240
# Loading: /Users/madamek/Box/taVNS_clinical/2020015/210930/HR18829_210930_013433.vital
# Compressed file ended before the end-of-stream marker was reached
# Removing data:
# 0:00:08.738000
# 0 outlier(s) have been deleted.
# 2 ectopic beat(s) have been deleted with malik rule.
# Array size for subject: 1260855 1260855
